# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook explores the diabetes dataset through statistical summaries and visualisations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
